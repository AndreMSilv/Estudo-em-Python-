# %%
import random

# %%
print("Gerador de jogos de loteria:\n")
# Out:
# Gerador de jogos de loteria:

# %%
numero_minimo = int(1)
numero_maximo = int(26)
array_jogos = []
indice_jogos = int(0)
indice_numeros = int(0)

# %%
qtd_jogos = int(input("Digite a quantidade de jogos:"))
qtd_numeros = int(input("Digite a quantidade de numeros por jogo:"))
# Out:
# Digite a quantidade de jogos:10
# Digite a quantidade de numeros por jogo:15

# %%
print("\n")

# %%
for indice_jogos in range(qtd_jogos):
  array_jogos = []
  for inidice_numeros in range(qtd_numeros):
    numero_sorteado=int(random.randrange(numero_minimo, numero_maximo))
    while numero_sorteado in array_jogos:
      numero_sorteado = int(random.randrange(numero_minimo, numero_maximo))
    array_jogos.append(numero_sorteado)
  print("jogos" + str(indice_jogos) + ":" + str(array_jogos))
  print ("resultado:" ,sorted(array_jogos[0:15]))
# Out:
# jogos0:[5, 22, 20, 11, 13, 21, 12, 14, 15, 8, 16, 17, 1, 23, 19]
# resultado: [1, 5, 8, 11, 12, 13, 14, 15, 16, 17, 19, 20, 21, 22, 23]
# jogos1:[23, 22, 10, 14, 12, 7, 17, 4, 16, 24, 20, 11, 6, 19, 5]
# resultado: [4, 5, 6, 7, 10, 11, 12, 14, 16, 17, 19, 20, 22, 23, 24]
# jogos2:[19, 3, 21, 2, 22, 20, 14, 17, 1, 12, 6, 5, 11, 9, 23]
# resultado: [1, 2, 3, 5, 6, 9, 11, 12, 14, 17, 19, 20, 21, 22, 23]
# jogos3:[8, 20, 5, 12, 23, 6, 24, 22, 19, 15, 3, 21, 11, 4, 18]
# resultado: [3, 4, 5, 6, 8, 11, 12, 15, 18, 19, 20, 21, 22, 23, 24]
# jogos4:[21, 13, 1, 11, 5, 6, 23, 8, 24, 3, 14, 17, 16, 22, 2]
# resultado: [1, 2, 3, 5, 6, 8, 11, 13, 14, 16, 17, 21, 22, 23, 24]
# jogos5:[24, 8, 1, 9, 20, 3, 11, 13, 19, 15, 22, 12, 14, 4, 2]
# resultado: [1, 2, 3, 4, 8, 9, 11, 12, 13, 14, 15, 19, 20, 22, 24]
# jogos6:[15, 8, 6, 14, 23, 3, 17, 22, 12, 2, 20, 18, 5, 9, 16]
# resultado: [2, 3, 5, 6, 8, 9, 12, 14, 15, 16, 17, 18, 20, 22, 23]
# jogos7:[7, 2, 9, 10, 22, 17, 1, 23, 5, 3, 16, 12, 20, 8, 4]
# resultado: [1, 2, 3, 4, 5, 7, 8, 9, 10, 12, 16, 17, 20, 22, 23]
# jogos8:[15, 18, 7, 1, 2, 13, 3, 24, 11, 23, 17, 6, 22, 14, 10]
# resultado: [1, 2, 3, 6, 7, 10, 11, 13, 14, 15, 17, 18, 22, 23, 24]
# jogos9:[6, 11, 13, 17, 19, 9, 14, 15, 12, 5, 2, 10, 8, 24, 22]
# resultado: [2, 5, 6, 8, 9, 10, 11, 12, 13, 14, 15, 17, 19, 22, 24]
