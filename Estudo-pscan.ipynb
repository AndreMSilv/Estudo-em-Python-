# %%
import socket

# %%
ip = input("Digite host ou Ip a ser Verificado: ")

ports = []
count = 0
# Out:
# Digite host ou Ip a ser Verificado: google.com

# %%
while count <10:
  ports.append(int(input("Digite a Porta a ser Verificada: ")))
  count +=1
# Out:
# Digite a Porta a ser Verificada: 234
# Digite a Porta a ser Verificada: 345
# Digite a Porta a ser Verificada: 27
# Digite a Porta a ser Verificada: 40
# Digite a Porta a ser Verificada: 87
# Digite a Porta a ser Verificada: 90
# Digite a Porta a ser Verificada: 123
# Digite a Porta a ser Verificada: 100
# Digite a Porta a ser Verificada: 180
# Digite a Porta a ser Verificada: 500

# %%
for port in ports:
  client =socket.socket(socket.AF_INET,socket.SOCK_STREAM)
  client.settimeout(0.05)
  code = client.connect_ex((ip, port))

# %%
if code == 0:
   print(str(port),"-->Porta Aberta")
else:
   print(str(port),"-->Porta Fechada")
# Out:
# 500 -->Porta Fechada

# %%
print(" Scan Finalizado")
# Out:
#  Scan Finalizado
